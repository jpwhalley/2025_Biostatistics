# %% [markdown]
# # SGPS BioStatistics
# ## Exercise 2: Getting publically available data
#
# #### Gene Expression data from Gene Expression Omnibus
# + https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE123336
#
# #### Specifically from this paper
# 1.	LaRocca D, Barns S, Hicks SD, Brindle A et al. Comparison of serum and saliva miRNAs for identification and characterization of mTBI in adult mixed martial arts fighters. *PLoS One* 2019;14(1):e0207785.

# %%
# Import the packages we need
import pandas as pd
import numpy as np
import GEOparse

# %%
# Get the data in
human_expression = pd.read_csv('GSE123336_MMA_CountMatrix.csv.gz', index_col=0, compression='gzip')
human_expression = human_expression.apply(pd.to_numeric, errors='coerce')

# %%
# Get the data straight (off the omnibus)
gse = GEOparse.get_GEO(geo="GSE123336", destdir=".")
# Out:
# 25-Aug-2025 11:36:58 DEBUG utils - Directory . already exists. Skipping.
# 25-Aug-2025 11:36:58 INFO GEOparse - File already exist: using local version.
# 25-Aug-2025 11:36:58 INFO GEOparse - Parsing ./GSE123336_family.soft.gz:
# 25-Aug-2025 11:36:58 DEBUG GEOparse - DATABASE: GeoMiame
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SERIES: GSE123336
# 25-Aug-2025 11:36:58 DEBUG GEOparse - PLATFORM: GPL18573
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500956
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500957
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500958
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500959
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500960
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500961
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500962
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500963
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500964
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500965
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500966
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500967
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500968
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500969
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500970
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500971
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500972
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500973
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500974
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500975
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500976
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500977
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500978
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500979
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500980
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500981
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500982
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500983
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500984
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500985
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500986
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500987
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500988
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500989
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500990
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500991
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500992
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500993
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500994
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500995
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500996
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500997
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500998
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3500999
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501000
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501001
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501002
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501003
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501004
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501005
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501006
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501007
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501008
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501009
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501010
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501011
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501012
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501013
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501014
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501015
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501016
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501017
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501018
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501019
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501020
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501021
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501022
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501023
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501024
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501025
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501026
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501027
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501028
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501029
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501030
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501031
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501032
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501033
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501034
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501035
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501036
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501037
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501038
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501039
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501040
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501041
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501042
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501043
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501044
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501045
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501046
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501047
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501048
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501049
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501050
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501051
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501052
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501053
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501054
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501055
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501056
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501057
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501058
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501059
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501060
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501061
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501062
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501063
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501064
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501065
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501066
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501067
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501068
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501069
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501070
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501071
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501072
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501073
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501074
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501075
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501076
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501077
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501078
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501079
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501080
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501081
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501082
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501083
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501084
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501085
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501086
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501087
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501088
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501089
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501090
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501091
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501092
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501093
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501094
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501095
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501096
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501097
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501098
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501099
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501100
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501101
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501102
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501103
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501104
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501105
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501106
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501107
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501108
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501109
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501110
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501111
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501112
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501113
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501114
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501115
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501116
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501117
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501118
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501119
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501120
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501121
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501122
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501123
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501124
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501125
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501126
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501127
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501128
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501129
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501130
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501131
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501132
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501133
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501134
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501135
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501136
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501137
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501138
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501139
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501140
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501141
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501142
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501143
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501144
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501145
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501146
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501147
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501148
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501149
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501150
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501151
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501152
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501153
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501154
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501155
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501156
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501157
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501158
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501159
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501160
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501161
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501162
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501163
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501164
# 25-Aug-2025 11:36:58 DEBUG GEOparse - SAMPLE: GSM3501165
# 25-Aug-2025 11:36:59 DEBUG GEOparse - SAMPLE: GSM3501166
# 25-Aug-2025 11:36:59 DEBUG GEOparse - SAMPLE: GSM3501167
# 25-Aug-2025 11:36:59 DEBUG GEOparse - SAMPLE: GSM3501168
# 25-Aug-2025 11:36:59 DEBUG GEOparse - SAMPLE: GSM3501169
# 25-Aug-2025 11:36:59 DEBUG GEOparse - SAMPLE: GSM3501170
# 25-Aug-2025 11:36:59 DEBUG GEOparse - SAMPLE: GSM3501171
# 25-Aug-2025 11:36:59 DEBUG GEOparse - SAMPLE: GSM3501172
# 25-Aug-2025 11:36:59 DEBUG GEOparse - SAMPLE: GSM3501173

# %%
gse.gsms
# Out:
# {'GSM3500956': <SAMPLE: GSM3500956>,
#  'GSM3500957': <SAMPLE: GSM3500957>,
#  'GSM3500958': <SAMPLE: GSM3500958>,
#  'GSM3500959': <SAMPLE: GSM3500959>,
#  'GSM3500960': <SAMPLE: GSM3500960>,
#  'GSM3500961': <SAMPLE: GSM3500961>,
#  'GSM3500962': <SAMPLE: GSM3500962>,
#  'GSM3500963': <SAMPLE: GSM3500963>,
#  'GSM3500964': <SAMPLE: GSM3500964>,
#  'GSM3500965': <SAMPLE: GSM3500965>,
#  'GSM3500966': <SAMPLE: GSM3500966>,
#  'GSM3500967': <SAMPLE: GSM3500967>,
#  'GSM3500968': <SAMPLE: GSM3500968>,
#  'GSM3500969': <SAMPLE: GSM3500969>,
#  'GSM3500970': <SAMPLE: GSM3500970>,
#  'GSM3500971': <SAMPLE: GSM3500971>,
#  'GSM3500972': <SAMPLE: GSM3500972>,
#  'GSM3500973': <SAMPLE: GSM3500973>,
#  'GSM3500974': <SAMPLE: GSM3500974>,
#  'GSM3500975': <SAMPLE: GSM3500975>,
#  'GSM3500976': <SAMPLE: GSM3500976>,
#  'GSM3500977': <SAMPLE: GSM3500977>,
#  'GSM3500978': <SAMPLE: GSM3500978>,
#  'GSM3500979': <SAMPLE: GSM3500979>,
#  'GSM3500980': <SAMPLE: GSM3500980>,
#  'GSM3500981': <SAMPLE: GSM3500981>,
#  'GSM3500982': <SAMPLE: GSM3500982>,
#  'GSM3500983': <SAMPLE: GSM3500983>,
#  'GSM3500984': <SAMPLE: GSM3500984>,
#  'GSM3500985': <SAMPLE: GSM3500985>,
#  'GSM3500986': <SAMPLE: GSM3500986>,
#  'GSM3500987': <SAMPLE: GSM3500987>,
#  'GSM3500988': <SAMPLE: GSM3500988>,
#  'GSM3500989': <SAMPLE: GSM3500989>,
#  'GSM3500990': <SAMPLE: GSM3500990>,
#  'GSM3500991': <SAMPLE: GSM3500991>,
#  'GSM3500992': <SAMPLE: GSM3500992>,
#  'GSM3500993': <SAMPLE: GSM3500993>,
#  'GSM3500994': <SAMPLE: GSM3500994>,
#  'GSM3500995': <SAMPLE: GSM3500995>,
#  'GSM3500996': <SAMPLE: GSM3500996>,
#  'GSM3500997': <SAMPLE: GSM3500997>,
#  'GSM3500998': <SAMPLE: GSM3500998>,
#  'GSM3500999': <SAMPLE: GSM3500999>,
#  'GSM3501000': <SAMPLE: GSM3501000>,
#  'GSM3501001': <SAMPLE: GSM3501001>,
#  'GSM3501002': <SAMPLE: GSM3501002>,
#  'GSM3501003': <SAMPLE: GSM3501003>,
#  'GSM3501004': <SAMPLE: GSM3501004>,
#  'GSM3501005': <SAMPLE: GSM3501005>,
#  'GSM3501006': <SAMPLE: GSM3501006>,
#  'GSM3501007': <SAMPLE: GSM3501007>,
#  'GSM3501008': <SAMPLE: GSM3501008>,
#  'GSM3501009': <SAMPLE: GSM3501009>,
#  'GSM3501010': <SAMPLE: GSM3501010>,
#  'GSM3501011': <SAMPLE: GSM3501011>,
#  'GSM3501012': <SAMPLE: GSM3501012>,
#  'GSM3501013': <SAMPLE: GSM3501013>,
#  'GSM3501014': <SAMPLE: GSM3501014>,
#  'GSM3501015': <SAMPLE: GSM3501015>,
#  'GSM3501016': <SAMPLE: GSM3501016>,
#  'GSM3501017': <SAMPLE: GSM3501017>,
#  'GSM3501018': <SAMPLE: GSM3501018>,
#  'GSM3501019': <SAMPLE: GSM3501019>,
#  'GSM3501020': <SAMPLE: GSM3501020>,
#  'GSM3501021': <SAMPLE: GSM3501021>,
#  'GSM3501022': <SAMPLE: GSM3501022>,
#  'GSM3501023': <SAMPLE: GSM3501023>,
#  'GSM3501024': <SAMPLE: GSM3501024>,
#  'GSM3501025': <SAMPLE: GSM3501025>,
#  'GSM3501026': <SAMPLE: GSM3501026>,
#  'GSM3501027': <SAMPLE: GSM3501027>,
#  'GSM3501028': <SAMPLE: GSM3501028>,
#  'GSM3501029': <SAMPLE: GSM3501029>,
#  'GSM3501030': <SAMPLE: GSM3501030>,
#  'GSM3501031': <SAMPLE: GSM3501031>,
#  'GSM3501032': <SAMPLE: GSM3501032>,
#  'GSM3501033': <SAMPLE: GSM3501033>,
#  'GSM3501034': <SAMPLE: GSM3501034>,
#  'GSM3501035': <SAMPLE: GSM3501035>,
#  'GSM3501036': <SAMPLE: GSM3501036>,
#  'GSM3501037': <SAMPLE: GSM3501037>,
#  'GSM3501038': <SAMPLE: GSM3501038>,
#  'GSM3501039': <SAMPLE: GSM3501039>,
#  'GSM3501040': <SAMPLE: GSM3501040>,
#  'GSM3501041': <SAMPLE: GSM3501041>,
#  'GSM3501042': <SAMPLE: GSM3501042>,
#  'GSM3501043': <SAMPLE: GSM3501043>,
#  'GSM3501044': <SAMPLE: GSM3501044>,
#  'GSM3501045': <SAMPLE: GSM3501045>,
#  'GSM3501046': <SAMPLE: GSM3501046>,
#  'GSM3501047': <SAMPLE: GSM3501047>,
#  'GSM3501048': <SAMPLE: GSM3501048>,
#  'GSM3501049': <SAMPLE: GSM3501049>,
#  'GSM3501050': <SAMPLE: GSM3501050>,
#  'GSM3501051': <SAMPLE: GSM3501051>,
#  'GSM3501052': <SAMPLE: GSM3501052>,
#  'GSM3501053': <SAMPLE: GSM3501053>,
#  'GSM3501054': <SAMPLE: GSM3501054>,
#  'GSM3501055': <SAMPLE: GSM3501055>,
#  'GSM3501056': <SAMPLE: GSM3501056>,
#  'GSM3501057': <SAMPLE: GSM3501057>,
#  'GSM3501058': <SAMPLE: GSM3501058>,
#  'GSM3501059': <SAMPLE: GSM3501059>,
#  'GSM3501060': <SAMPLE: GSM3501060>,
#  'GSM3501061': <SAMPLE: GSM3501061>,
#  'GSM3501062': <SAMPLE: GSM3501062>,
#  'GSM3501063': <SAMPLE: GSM3501063>,
#  'GSM3501064': <SAMPLE: GSM3501064>,
#  'GSM3501065': <SAMPLE: GSM3501065>,
#  'GSM3501066': <SAMPLE: GSM3501066>,
#  'GSM3501067': <SAMPLE: GSM3501067>,
#  'GSM3501068': <SAMPLE: GSM3501068>,
#  'GSM3501069': <SAMPLE: GSM3501069>,
#  'GSM3501070': <SAMPLE: GSM3501070>,
#  'GSM3501071': <SAMPLE: GSM3501071>,
#  'GSM3501072': <SAMPLE: GSM3501072>,
#  'GSM3501073': <SAMPLE: GSM3501073>,
#  'GSM3501074': <SAMPLE: GSM3501074>,
#  'GSM3501075': <SAMPLE: GSM3501075>,
#  'GSM3501076': <SAMPLE: GSM3501076>,
#  'GSM3501077': <SAMPLE: GSM3501077>,
#  'GSM3501078': <SAMPLE: GSM3501078>,
#  'GSM3501079': <SAMPLE: GSM3501079>,
#  'GSM3501080': <SAMPLE: GSM3501080>,
#  'GSM3501081': <SAMPLE: GSM3501081>,
#  'GSM3501082': <SAMPLE: GSM3501082>,
#  'GSM3501083': <SAMPLE: GSM3501083>,
#  'GSM3501084': <SAMPLE: GSM3501084>,
#  'GSM3501085': <SAMPLE: GSM3501085>,
#  'GSM3501086': <SAMPLE: GSM3501086>,
#  'GSM3501087': <SAMPLE: GSM3501087>,
#  'GSM3501088': <SAMPLE: GSM3501088>,
#  'GSM3501089': <SAMPLE: GSM3501089>,
#  'GSM3501090': <SAMPLE: GSM3501090>,
#  'GSM3501091': <SAMPLE: GSM3501091>,
#  'GSM3501092': <SAMPLE: GSM3501092>,
#  'GSM3501093': <SAMPLE: GSM3501093>,
#  'GSM3501094': <SAMPLE: GSM3501094>,
#  'GSM3501095': <SAMPLE: GSM3501095>,
#  'GSM3501096': <SAMPLE: GSM3501096>,
#  'GSM3501097': <SAMPLE: GSM3501097>,
#  'GSM3501098': <SAMPLE: GSM3501098>,
#  'GSM3501099': <SAMPLE: GSM3501099>,
#  'GSM3501100': <SAMPLE: GSM3501100>,
#  'GSM3501101': <SAMPLE: GSM3501101>,
#  'GSM3501102': <SAMPLE: GSM3501102>,
#  'GSM3501103': <SAMPLE: GSM3501103>,
#  'GSM3501104': <SAMPLE: GSM3501104>,
#  'GSM3501105': <SAMPLE: GSM3501105>,
#  'GSM3501106': <SAMPLE: GSM3501106>,
#  'GSM3501107': <SAMPLE: GSM3501107>,
#  'GSM3501108': <SAMPLE: GSM3501108>,
#  'GSM3501109': <SAMPLE: GSM3501109>,
#  'GSM3501110': <SAMPLE: GSM3501110>,
#  'GSM3501111': <SAMPLE: GSM3501111>,
#  'GSM3501112': <SAMPLE: GSM3501112>,
#  'GSM3501113': <SAMPLE: GSM3501113>,
#  'GSM3501114': <SAMPLE: GSM3501114>,
#  'GSM3501115': <SAMPLE: GSM3501115>,
#  'GSM3501116': <SAMPLE: GSM3501116>,
#  'GSM3501117': <SAMPLE: GSM3501117>,
#  'GSM3501118': <SAMPLE: GSM3501118>,
#  'GSM3501119': <SAMPLE: GSM3501119>,
#  'GSM3501120': <SAMPLE: GSM3501120>,
#  'GSM3501121': <SAMPLE: GSM3501121>,
#  'GSM3501122': <SAMPLE: GSM3501122>,
#  'GSM3501123': <SAMPLE: GSM3501123>,
#  'GSM3501124': <SAMPLE: GSM3501124>,
#  'GSM3501125': <SAMPLE: GSM3501125>,
#  'GSM3501126': <SAMPLE: GSM3501126>,
#  'GSM3501127': <SAMPLE: GSM3501127>,
#  'GSM3501128': <SAMPLE: GSM3501128>,
#  'GSM3501129': <SAMPLE: GSM3501129>,
#  'GSM3501130': <SAMPLE: GSM3501130>,
#  'GSM3501131': <SAMPLE: GSM3501131>,
#  'GSM3501132': <SAMPLE: GSM3501132>,
#  'GSM3501133': <SAMPLE: GSM3501133>,
#  'GSM3501134': <SAMPLE: GSM3501134>,
#  'GSM3501135': <SAMPLE: GSM3501135>,
#  'GSM3501136': <SAMPLE: GSM3501136>,
#  'GSM3501137': <SAMPLE: GSM3501137>,
#  'GSM3501138': <SAMPLE: GSM3501138>,
#  'GSM3501139': <SAMPLE: GSM3501139>,
#  'GSM3501140': <SAMPLE: GSM3501140>,
#  'GSM3501141': <SAMPLE: GSM3501141>,
#  'GSM3501142': <SAMPLE: GSM3501142>,
#  'GSM3501143': <SAMPLE: GSM3501143>,
#  'GSM3501144': <SAMPLE: GSM3501144>,
#  'GSM3501145': <SAMPLE: GSM3501145>,
#  'GSM3501146': <SAMPLE: GSM3501146>,
#  'GSM3501147': <SAMPLE: GSM3501147>,
#  'GSM3501148': <SAMPLE: GSM3501148>,
#  'GSM3501149': <SAMPLE: GSM3501149>,
#  'GSM3501150': <SAMPLE: GSM3501150>,
#  'GSM3501151': <SAMPLE: GSM3501151>,
#  'GSM3501152': <SAMPLE: GSM3501152>,
#  'GSM3501153': <SAMPLE: GSM3501153>,
#  'GSM3501154': <SAMPLE: GSM3501154>,
#  'GSM3501155': <SAMPLE: GSM3501155>,
#  'GSM3501156': <SAMPLE: GSM3501156>,
#  'GSM3501157': <SAMPLE: GSM3501157>,
#  'GSM3501158': <SAMPLE: GSM3501158>,
#  'GSM3501159': <SAMPLE: GSM3501159>,
#  'GSM3501160': <SAMPLE: GSM3501160>,
#  'GSM3501161': <SAMPLE: GSM3501161>,
#  'GSM3501162': <SAMPLE: GSM3501162>,
#  'GSM3501163': <SAMPLE: GSM3501163>,
#  'GSM3501164': <SAMPLE: GSM3501164>,
#  'GSM3501165': <SAMPLE: GSM3501165>,
#  'GSM3501166': <SAMPLE: GSM3501166>,
#  'GSM3501167': <SAMPLE: GSM3501167>,
#  'GSM3501168': <SAMPLE: GSM3501168>,
#  'GSM3501169': <SAMPLE: GSM3501169>,
#  'GSM3501170': <SAMPLE: GSM3501170>,
#  'GSM3501171': <SAMPLE: GSM3501171>,
#  'GSM3501172': <SAMPLE: GSM3501172>,
#  'GSM3501173': <SAMPLE: GSM3501173>}

# %%
gse.gsms['GSM3500956'].metadata
# Out:
# {'title': ['MMA001-2533'],
#  'geo_accession': ['GSM3500956'],
#  'status': ['Public on Dec 05 2018'],
#  'submission_date': ['Dec 04 2018'],
#  'last_update_date': ['Dec 05 2018'],
#  'type': ['SRA'],
#  'channel_count': ['1'],
#  'source_name_ch1': ['Saliva'],
#  'organism_ch1': ['Homo sapiens'],
#  'taxid_ch1': ['9606'],
#  'characteristics_ch1': ['tissue: Saliva',
#   'timepoint: 0d post',
#   'hits to the head: 2',
#   'subject: MMA001'],
#  'molecule_ch1': ['total RNA'],
#  'extract_protocol_ch1': ['Saliva was collected in an RNA stabilizing container (Oragene RNA RE-100, DNA Genotek) and RNA was harvested using Qiazol reagent followed by RNeasy (Qiagen).',
#   'llumina TruSeq RNA Sample Prep Kit (Cat#FC-122-1001) was used with 250-500 nanograms of total RNA for the construction of sequencing libraries.'],
#  'description': ['Sample 1'],
#  'data_processing': ['Raw sequencing intensities were obtained on a NextSeq500 instrument and converted to base calls using bcl2fastq software (Illumina)',
#   'TruSeq Small RNA adapters were trimmed using cutadapt in Partek Flow (Partek), with minimum length set to 19',
#   'Alignment to miRbase 21 index of hg38 was performed using Shrimp2 in Partek Flow (Partek)',
#   'Quantification was performed in Partek Flow (Partek)',
#   'Normalization was performed to total read counts',
#   'Genome_build: hg38',
#   'Supplementary_files_format_and_content: a single data matrix of raw count abundance is provided as a comma separated value (CSV) file for the combined set of 218 samples'],
#  'platform_id': ['GPL18573'],
#  'contact_name': ['Frank,A,Middleton'],
#  'contact_email': ['middletf@upstate.edu'],
#  'contact_phone': ['315-464-7721'],
#  'contact_department': ['Neuroscience and Physiology'],
#  'contact_institute': ['SUNY Upstate Medical Univ'],
#  'contact_address': ['505 Irving Avenue'],
#  'contact_city': ['Syracuse'],
#  'contact_state': ['NY'],
#  'contact_zip/postal_code': ['13210'],
#  'contact_country': ['USA'],
#  'instrument_model': ['Illumina NextSeq 500'],
#  'library_selection': ['size fractionation'],
#  'library_source': ['transcriptomic'],
#  'library_strategy': ['miRNA-Seq'],
#  'relation': ['BioSample: https://www.ncbi.nlm.nih.gov/biosample/SAMN10520027',
#   'SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX5095235'],
#  'supplementary_file_1': ['NONE'],
#  'series_id': ['GSE123336'],
#  'data_row_count': ['0']}

# %%
# And collect the metadata
meta = {}
for key in gse.gsms:
    # print(key)
    samp = gse.gsms[key].metadata['description'][0]
    characteristics = {}
    for item in gse.gsms[key].metadata['characteristics_ch1']:
        temp = item.split(': ')
        characteristics[temp[0]] = temp[1]

    if samp not in meta:
        meta[samp] = {}
        meta[samp] = characteristics
    else:
        meta[samp] = characteristics

metadata = pd.DataFrame(meta).T
metadata.to_csv('GSE123336_metadata.csv')

# %%
metadata
# Out:
#             tissue timepoint hits to the head subject
# Sample 1    Saliva   0d post                2  MMA001
# Sample 2     Serum   0d post                2  MMA001
# Sample 3    Saliva    0d pre                0  MMA001
# Sample 4     Serum    0d pre                0  MMA001
# Sample 5    Saliva  1wk post                2  MMA001
# ...            ...       ...              ...     ...
# Sample 214   Serum    0d pre                0  MMA040
# Sample 215   Serum   0d post               35  MMA041
# Sample 216   Serum    0d pre                0  MMA041
# Sample 217   Serum   0d post                7  MMA042
# Sample 218   Serum    0d pre                0  MMA042
#
# [218 rows x 4 columns]

# %%
# Can we see which miRNA are differentially expressed in Saliva pre and post fight?
# Filter for saliva samples only
saliva_samples = metadata[(metadata['tissue'] == 'Saliva') & 
                          (metadata['timepoint'].isin(['0d pre', '0d post']))]

# Get the corresponding sample names
saliva_sample_names = saliva_samples.index

# Subset the expression data
saliva_expression = human_expression[saliva_sample_names]
saliva_expression

pre_fight_samples = saliva_samples[saliva_samples['timepoint'] == '0d pre'].index
post_fight_samples = saliva_samples[saliva_samples['timepoint'] == '0d post'].index

pre_fight_expression = saliva_expression[pre_fight_samples]
post_fight_expression = saliva_expression[post_fight_samples]

# %%
from scipy.stats import mannwhitneyu

# Initialize a list to store results
diff_expression_results = []

# Iterate through each miRNA
for miRNA in saliva_expression.index:
    # Extract expression levels for this miRNA
    pre_values = pre_fight_expression.loc[miRNA]
    post_values = post_fight_expression.loc[miRNA]
    
    # Perform the Mann-Whitney U test
    stat, p_value = mannwhitneyu(pre_values, post_values, alternative='two-sided')
    
    # Store the results
    diff_expression_results.append({
        'miRNA': miRNA,
        'statistic': stat,
        'p_value': p_value
    })

# Convert the results to a DataFrame
diff_expression_df = pd.DataFrame(diff_expression_results)

# Apply multiple testing correction (e.g., Benjamini-Hochberg)
from statsmodels.stats.multitest import multipletests

diff_expression_df['Significant'], diff_expression_df['adjusted_p_value'], _, _ = multipletests(diff_expression_df['p_value'], method='fdr_bh')

# Sort the results by adjusted p-value
diff_expression_df = diff_expression_df.sort_values('p_value')
diff_expression_df
# Out:
#                   miRNA  statistic   p_value  Significant  adjusted_p_value
# 1287     hsa-miR-486-3p       96.0  0.001339        False               1.0
# 351      hsa-miR-204-5p      108.0  0.004007        False               1.0
# 960     hsa-miR-449c-5p      121.5  0.007006        False               1.0
# 992    hsa-miR-4524b-3p      132.0  0.010144        False               1.0
# 47    hsa-miR-1185-2-3p      142.0  0.011817        False               1.0
# ...                 ...        ...       ...          ...               ...
# 1992    hsa-miR-6805-3p      208.5  1.000000        False               1.0
# 547       hsa-miR-3155a      209.5  1.000000        False               1.0
# 322     hsa-miR-196b-3p      209.0  1.000000        False               1.0
# 325      hsa-miR-197-5p      208.5  1.000000        False               1.0
# 1893    hsa-miR-6757-5p      208.5  1.000000        False               1.0
#
# [2347 rows x 5 columns]

# %%
# Can we see which miRNA are differentially expressed in Serum pre and post fight?
# Filter for serum samples only
serum_samples = metadata[(metadata['tissue'] == 'Serum') & 
                          (metadata['timepoint'].isin(['0d pre', '0d post']))]

# Get the corresponding sample names
serum_sample_names = serum_samples.index

# Subset the expression data
serum_expression = human_expression[serum_sample_names]
serum_expression

pre_fight_samples = serum_samples[serum_samples['timepoint'] == '0d pre'].index
post_fight_samples = serum_samples[serum_samples['timepoint'] == '0d post'].index

pre_fight_expression = serum_expression[pre_fight_samples]
post_fight_expression = serum_expression[post_fight_samples]

# %%
from scipy.stats import mannwhitneyu

# Initialize a list to store results
diff_expression_results = []

# Iterate through each miRNA
for miRNA in serum_expression.index:
    # Extract expression levels for this miRNA
    pre_values = pre_fight_expression.loc[miRNA]
    post_values = post_fight_expression.loc[miRNA]
    
    # Perform the Mann-Whitney U test
    stat, p_value = mannwhitneyu(pre_values, post_values, alternative='two-sided')
    
    # Store the results
    diff_expression_results.append({
        'miRNA': miRNA,
        'statistic': stat,
        'p_value': p_value
    })

# Convert the results to a DataFrame
diff_expression_df = pd.DataFrame(diff_expression_results)

# Apply multiple testing correction (e.g., Benjamini-Hochberg)
from statsmodels.stats.multitest import multipletests

diff_expression_df['Significant'], diff_expression_df['adjusted_p_value'], _, _ = multipletests(diff_expression_df['p_value'], method='fdr_bh')

# Sort the results by adjusted p-value
diff_expression_df = diff_expression_df.sort_values('p_value')
diff_expression_df
# Out:
#                   miRNA  statistic   p_value  Significant  adjusted_p_value
# 111   hsa-miR-125b-2-3p      473.5  0.000012         True          0.019786
# 829     hsa-miR-3934-5p      598.0  0.000017         True          0.019786
# 383      hsa-miR-214-3p      538.0  0.000032         True          0.024891
# 37       hsa-miR-10b-5p      520.0  0.000070         True          0.040821
# 35       hsa-miR-10a-5p      545.0  0.000160        False          0.074919
# ...                 ...        ...       ...          ...               ...
# 246     hsa-miR-1537-3p     1012.5  1.000000        False          1.000000
# 732        hsa-miR-3684     1012.5  1.000000        False          1.000000
# 1734        hsa-miR-639     1012.5  1.000000        False          1.000000
# 230        hsa-miR-147a     1012.5  1.000000        False          1.000000
# 1811     hsa-miR-670-3p     1012.5  1.000000        False          1.000000
#
# [2347 rows x 5 columns]

# %% [markdown]
# ### How about getting rat data for mTBI?
# #### Gene Expression data from Gene Expression Omnibus
# + https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE159011
#
# #### Specifically from this paper
# 1.	Das Gupta S, Ciszek R, Heiskanen M, Lapinlampi N et al. Plasma miR-9-3p and miR-136-3p as Potential Novel Diagnostic Biomarkers for Experimental and Human Mild Traumatic Brain Injury. *Int J Mol Sci* 2021 Feb 4;22(4).

# %%
rat_expression = pd.read_csv("GSE159011_Raw_counts_matrix.txt", index_col=0, sep='\t')

# %%
rat_expression
# Out:
#                          20657-020-UMIs  20657-002-UMIs  20657-012-UMIs  \
# miRNA
# rno-let-7a-1-3p/7c-2-3p             160             308             817
# rno-let-7a-2-3p                      48              55              48
# rno-let-7a-5p                     36267           38882           58248
# rno-let-7b-3p                       441             650             994
# rno-let-7b-5p                     88155          135591          214262
# ...                                 ...             ...             ...
# rno-miR-99b-5p                     1792            2422            5632
# rno-miR-9a-3p                        23              18              33
# rno-miR-9a-5p                        52              75              56
# rno-miR-9b-3p                         0               0               4
# rno-miR-9b-5p                         0               0               4
#
#                          20657-006-UMIs  20657-007-UMIs  20657-019-UMIs  \
# miRNA
# rno-let-7a-1-3p/7c-2-3p             358             548             179
# rno-let-7a-2-3p                      40              55              38
# rno-let-7a-5p                     45855           61422           41501
# rno-let-7b-3p                       770             772             579
# rno-let-7b-5p                    128710          178067           99188
# ...                                 ...             ...             ...
# rno-miR-99b-5p                     3005            3995            1925
# rno-miR-9a-3p                       655             163             303
# rno-miR-9a-5p                       395             127             387
# rno-miR-9b-3p                        21               6              19
# rno-miR-9b-5p                        23               3              17
#
#                          20657-018-UMIs  20657-008-UMIs  20657-005-UMIs  \
# miRNA
# rno-let-7a-1-3p/7c-2-3p             793             320             232
# rno-let-7a-2-3p                      35              56              43
# rno-let-7a-5p                     73998           41453           42114
# rno-let-7b-3p                      1302             780             553
# rno-let-7b-5p                    243651          139027           95987
# ...                                 ...             ...             ...
# rno-miR-99b-5p                     5573            3163            2202
# rno-miR-9a-3p                       159              42             647
# rno-miR-9a-5p                       150              86             421
# rno-miR-9b-3p                         0              13              24
# rno-miR-9b-5p                         0               0              20
#
#                          20657-004-UMIs  ...  20657-004-READs  \
# miRNA                                    ...
# rno-let-7a-1-3p/7c-2-3p             311  ...              490
# rno-let-7a-2-3p                      50  ...               83
# rno-let-7a-5p                     46192  ...            66583
# rno-let-7b-3p                       636  ...              819
# rno-let-7b-5p                    125310  ...           181639
# ...                                 ...  ...              ...
# rno-miR-99b-5p                     2921  ...             4660
# rno-miR-9a-3p                        34  ...               53
# rno-miR-9a-5p                        85  ...              136
# rno-miR-9b-3p                         5  ...                5
# rno-miR-9b-5p                         7  ...               16
#
#                          20657-003-READs  20657-011-READs  20657-010-READs  \
# miRNA
# rno-let-7a-1-3p/7c-2-3p              799              447              318
# rno-let-7a-2-3p                      219               83               82
# rno-let-7a-5p                      64615            69738            41452
# rno-let-7b-3p                        899              747              558
# rno-let-7b-5p                     186234           163980           111789
# ...                                  ...              ...              ...
# rno-miR-99b-5p                      4829             4179             3320
# rno-miR-9a-3p                        225              141               76
# rno-miR-9a-5p                        401              176              178
# rno-miR-9b-3p                         95               12                4
# rno-miR-9b-5p                         18                0                0
#
#                          20657-013-READs  20657-001-READs  20657-015-READs  \
# miRNA
# rno-let-7a-1-3p/7c-2-3p              413              571              365
# rno-let-7a-2-3p                      113              120               96
# rno-let-7a-5p                      54041            53300            44454
# rno-let-7b-3p                        696              768              600
# rno-let-7b-5p                     143520           183815           114509
# ...                                  ...              ...              ...
# rno-miR-99b-5p                      4608             5087             4296
# rno-miR-9a-3p                        733              761               66
# rno-miR-9a-5p                        519              654              216
# rno-miR-9b-3p                         35               29                0
# rno-miR-9b-5p                         20               13                0
#
#                          20657-014-READs  20657-017-READs  20657-016-READs
# miRNA
# rno-let-7a-1-3p/7c-2-3p              394              486              762
# rno-let-7a-2-3p                      107              105               31
# rno-let-7a-5p                      56369            99764            51578
# rno-let-7b-3p                        670              943              630
# rno-let-7b-5p                     129363           213979           146829
# ...                                  ...              ...              ...
# rno-miR-99b-5p                      3322             5110             3231
# rno-miR-9a-3p                         45              221               20
# rno-miR-9a-5p                        137              401               75
# rno-miR-9b-3p                          0               18                5
# rno-miR-9b-5p                          0                0                0
#
# [748 rows x 38 columns]

# %%
rat_expression.sum()
# Out:
# 20657-020-UMIs     2894711
# 20657-002-UMIs     3322547
# 20657-012-UMIs     5041094
# 20657-006-UMIs     3584618
# 20657-007-UMIs     4221068
# 20657-019-UMIs     3232696
# 20657-018-UMIs     5866757
# 20657-008-UMIs     3625424
# 20657-005-UMIs     3524486
# 20657-004-UMIs     3757053
# 20657-003-UMIs     4446067
# 20657-011-UMIs     3779106
# 20657-010-UMIs     2886651
# 20657-013-UMIs     2968683
# 20657-001-UMIs     2851406
# 20657-015-UMIs     2409545
# 20657-014-UMIs     2908509
# 20657-017-UMIs     3389253
# 20657-016-UMIs     4090289
# 20657-020-READs    5005676
# 20657-002-READs    4828446
# 20657-012-READs    6826144
# 20657-006-READs    5844032
# 20657-007-READs    5002302
# 20657-019-READs    6482291
# 20657-018-READs    8876409
# 20657-008-READs    6066846
# 20657-005-READs    6257970
# 20657-004-READs    5729837
# 20657-003-READs    7700898
# 20657-011-READs    6504203
# 20657-010-READs    4803736
# 20657-013-READs    5576208
# 20657-001-READs    4764649
# 20657-015-READs    4871664
# 20657-014-READs    4898247
# 20657-017-READs    7588587
# 20657-016-READs    5013071
# dtype: int64

# %%
# Normalization
# Step 1: Calculate the sum of each column
column_sums = rat_expression.sum()

# Step 2: Determine the normalization factor to scale each column to sum to 1 million
normalization_factor = 1_000_000 / column_sums

# Step 3: Multiply each column by its respective normalization factor
normalized_df = rat_expression.multiply(normalization_factor, axis=1)

# Now each column in `normalized_df` should sum to 1 million
normalized_df
# Out:
#                          20657-020-UMIs  20657-002-UMIs  20657-012-UMIs  \
# miRNA
# rno-let-7a-1-3p/7c-2-3p       55.273221       92.699968      162.067996
# rno-let-7a-2-3p               16.581966       16.553566        9.521743
# rno-let-7a-5p              12528.711847    11702.468016    11554.634768
# rno-let-7b-3p                152.346815      195.633049      197.179422
# rno-let-7b-5p              30453.817324    40809.354992    42503.075721
# ...                                 ...             ...             ...
# rno-miR-99b-5p               619.060072      728.958838     1117.217810
# rno-miR-9a-3p                  7.945525        5.417531        6.546198
# rno-miR-9a-5p                 17.963797       22.573044       11.108700
# rno-miR-9b-3p                  0.000000        0.000000        0.793479
# rno-miR-9b-5p                  0.000000        0.000000        0.793479
#
#                          20657-006-UMIs  20657-007-UMIs  20657-019-UMIs  \
# miRNA
# rno-let-7a-1-3p/7c-2-3p       99.871172      129.824964       55.371739
# rno-let-7a-2-3p               11.158790       13.029878       11.754894
# rno-let-7a-5p              12792.158049    14551.293654    12837.891345
# rno-let-7b-3p                214.806710      182.892102      179.107469
# rno-let-7b-5p              35906.196978    42185.295285    30682.749012
# ...                                 ...             ...             ...
# rno-miR-99b-5p               838.304109      946.442938      595.478201
# rno-miR-9a-3p                182.725189       38.615820       93.729816
# rno-miR-9a-5p                110.193053       30.087172      119.714319
# rno-miR-9b-3p                  5.858365        1.421441        5.877447
# rno-miR-9b-5p                  6.416304        0.710721        5.258769
#
#                          20657-018-UMIs  20657-008-UMIs  20657-005-UMIs  \
# miRNA
# rno-let-7a-1-3p/7c-2-3p      135.168373       88.265538       65.825201
# rno-let-7a-2-3p                5.965817       15.446469       12.200361
# rno-let-7a-5p              12613.101241    11433.972964    11948.976390
# rno-let-7b-3p                221.928401      215.147249      156.902311
# rno-let-7b-5p              41530.780975    38347.790493    27234.325800
# ...                                 ...             ...             ...
# rno-miR-99b-5p               949.928555      872.449678      624.771953
# rno-miR-9a-3p                 27.101855       11.584852      183.572867
# rno-miR-9a-5p                 25.567788       23.721363      119.450042
# rno-miR-9b-3p                  0.000000        3.585787        6.809504
# rno-miR-9b-5p                  0.000000        0.000000        5.674586
#
#                          20657-004-UMIs  ...  20657-004-READs  \
# miRNA                                    ...
# rno-let-7a-1-3p/7c-2-3p       82.777645  ...        85.517267
# rno-let-7a-2-3p               13.308303  ...        14.485578
# rno-let-7a-5p              12294.742715  ...     11620.400371
# rno-let-7b-3p                169.281615  ...       142.936003
# rno-let-7b-5p              33353.269171  ...     31700.552738
# ...                                 ...  ...              ...
# rno-miR-99b-5p               777.471066  ...       813.286661
# rno-miR-9a-3p                  9.049646  ...         9.249827
# rno-miR-9a-5p                 22.624115  ...        23.735405
# rno-miR-9b-3p                  1.330830  ...         0.872625
# rno-miR-9b-5p                  1.863162  ...         2.792401
#
#                          20657-003-READs  20657-011-READs  20657-010-READs  \
# miRNA
# rno-let-7a-1-3p/7c-2-3p       103.754134        68.724792        66.198476
# rno-let-7a-2-3p                28.438242        12.760979        17.070047
# rno-let-7a-5p                8390.579904     10721.990073      8629.117004
# rno-let-7b-3p                 116.739632       114.848814       116.159589
# rno-let-7b-5p               24183.413415     25211.390235     23271.262201
# ...                                  ...              ...              ...
# rno-miR-99b-5p                627.069726       642.507622       691.128738
# rno-miR-9a-3p                  29.217372        21.678290        15.821019
# rno-miR-9a-5p                  52.071849        27.059426        37.054493
# rno-miR-9b-3p                  12.336224         1.844961         0.832685
# rno-miR-9b-5p                   2.337390         0.000000         0.000000
#
#                          20657-013-READs  20657-001-READs  20657-015-READs  \
# miRNA
# rno-let-7a-1-3p/7c-2-3p        74.064669       119.840937        74.923065
# rno-let-7a-2-3p                20.264667        25.185486        19.705793
# rno-let-7a-5p                9691.352977     11186.553301      9125.013548
# rno-let-7b-3p                 124.816004       161.187109       123.161203
# rno-let-7b-5p               25737.920824     38578.917356     23505.110369
# ...                                  ...              ...              ...
# rno-miR-99b-5p                826.368026      1067.654721       881.834215
# rno-miR-9a-3p                 131.451338       159.717956        13.547732
# rno-miR-9a-5p                  93.074003       137.260898        44.338033
# rno-miR-9b-3p                   6.276667         6.086492         0.000000
# rno-miR-9b-5p                   3.586667         2.728428         0.000000
#
#                          20657-014-READs  20657-017-READs  20657-016-READs
# miRNA
# rno-let-7a-1-3p/7c-2-3p        80.436940        64.043543       152.002635
# rno-let-7a-2-3p                21.844550        13.836568         6.183834
# rno-let-7a-5p               11507.994595     13146.584470     10288.703272
# rno-let-7b-3p                 136.783629       124.265558       125.671470
# rno-let-7b-5p               26410.060579     28197.476026     29289.232089
# ...                                  ...              ...              ...
# rno-miR-99b-5p                678.201814       673.379642       644.515109
# rno-miR-9a-3p                   9.186960        29.122681         3.989570
# rno-miR-9a-5p                  27.969190        52.842512        14.960889
# rno-miR-9b-3p                   0.000000         2.371983         0.997393
# rno-miR-9b-5p                   0.000000         0.000000         0.000000
#
# [748 rows x 38 columns]

# %%
# We also want to do put this on a log2 scale
log2_df = np.log2(normalized_df + 1)
log2_df
# Out:
#                          20657-020-UMIs  20657-002-UMIs  20657-012-UMIs  \
# miRNA
# rno-let-7a-1-3p/7c-2-3p        5.814377        6.549977        7.349330
# rno-let-7a-2-3p                4.136025        4.133692        3.395302
# rno-let-7a-5p                 13.613066       13.514648       13.496309
# rno-let-7b-3p                  7.260654        7.619362        7.630663
# rno-let-7b-5p                 14.894383       15.316648       15.375314
# ...                                 ...             ...             ...
# rno-miR-99b-5p                 9.276264        9.511671       10.126986
# rno-miR-9a-3p                  3.161166        2.682018        2.915750
# rno-miR-9a-5p                  4.245176        4.559066        3.597972
# rno-miR-9b-3p                  0.000000        0.000000        0.842760
# rno-miR-9b-5p                  0.000000        0.000000        0.842760
#
#                          20657-006-UMIs  20657-007-UMIs  20657-019-UMIs  \
# miRNA
# rno-let-7a-1-3p/7c-2-3p        6.656370        7.031494        5.816900
# rno-let-7a-2-3p                3.603928        3.810431        3.672979
# rno-let-7a-5p                 13.643085       13.828959       13.648233
# rno-let-7b-3p                  7.753596        7.522716        7.492714
# rno-let-7b-5p                 15.131985       15.364487       14.905187
# ...                                 ...             ...             ...
# rno-miR-99b-5p                 9.713050        9.887895        9.220326
# rno-miR-9a-3p                  7.521406        5.308005        6.565747
# rno-miR-9a-5p                  6.796923        4.958247        6.915453
# rno-miR-9b-3p                  2.777865        1.275866        2.781873
# rno-miR-9b-5p                  2.890700        0.774604        2.645879
#
#                          20657-018-UMIs  20657-008-UMIs  20657-005-UMIs  \
# miRNA
# rno-let-7a-1-3p/7c-2-3p        7.089248        6.480031        6.062320
# rno-let-7a-2-3p                2.800293        4.039706        3.722505
# rno-let-7a-5p                 13.622750       13.481165       13.544720
# rno-let-7b-3p                  7.800437        7.755871        7.302888
# rno-let-7b-5p                 15.341928       15.226893       14.733192
# ...                                 ...             ...             ...
# rno-miR-99b-5p                 9.893193        9.770581        9.289493
# rno-miR-9a-3p                  4.812593        3.653616        7.528047
# rno-miR-9a-5p                  4.731606        4.627686        6.912291
# rno-miR-9b-3p                  0.000000        2.197169        2.965231
# rno-miR-9b-5p                  0.000000        0.000000        2.738678
#
#                          20657-004-UMIs  ...  20657-004-READs  \
# miRNA                                    ...
# rno-let-7a-1-3p/7c-2-3p        6.388493  ...         6.434916
# rno-let-7a-2-3p                3.838781  ...         3.952853
# rno-let-7a-5p                 13.585871  ...        13.504496
# rno-let-7b-3p                  7.411779  ...         7.169284
# rno-let-7b-5p                 15.025584  ...        14.952266
# ...                                 ...  ...              ...
# rno-miR-99b-5p                 9.604500  ...         9.669393
# rno-miR-9a-3p                  3.329073  ...         3.357528
# rno-miR-9a-5p                  4.562188  ...         4.628506
# rno-miR-9b-3p                  1.220844  ...         0.905062
# rno-miR-9b-5p                  1.517610  ...         1.923111
#
#                          20657-003-READs  20657-011-READs  20657-010-READs  \
# miRNA
# rno-let-7a-1-3p/7c-2-3p         6.710863         6.123600         6.070357
# rno-let-7a-2-3p                 4.879620         3.782511         4.175528
# rno-let-7a-5p                  13.034727        13.388420        13.075164
# rno-let-7b-3p                   6.879456         6.856099         6.872331
# rno-let-7b-5p                  14.561790        14.621845        14.506324
# ...                                  ...              ...              ...
# rno-miR-99b-5p                  9.294781         9.329813         9.434897
# rno-miR-9a-3p                   4.917306         4.503240         4.072193
# rno-miR-9a-5p                   5.729875         4.810414         5.249995
# rno-miR-9b-3p                   3.737278         1.508409         0.873959
# rno-miR-9b-5p                   1.738720         0.000000         0.000000
#
#                          20657-013-READs  20657-001-READs  20657-015-READs  \
# miRNA
# rno-let-7a-1-3p/7c-2-3p         6.230062         6.916965         6.246466
# rno-let-7a-2-3p                 4.410386         4.710695         4.371963
# rno-let-7a-5p                  13.242631        13.449607        13.155769
# rno-let-7b-3p                   6.975172         7.341515         6.956071
# rno-let-7b-5p                  14.651664        15.235562        14.520748
# ...                                  ...              ...              ...
# rno-miR-99b-5p                  9.692385        10.061580         9.785999
# rno-miR-9a-3p                   7.049319         7.328387         3.862722
# rno-miR-9a-5p                   6.555724         7.111249         5.502650
# rno-miR-9b-3p                   2.863278         2.825072         0.000000
# rno-miR-9b-5p                   2.197446         1.898567         0.000000
#
#                          20657-014-READs  20657-017-READs  20657-016-READs
# miRNA
# rno-let-7a-1-3p/7c-2-3p         6.347611         6.023334         7.257413
# rno-let-7a-2-3p                 4.513778         3.891086         2.844754
# rno-let-7a-5p                  13.490474        13.682510        13.328914
# rno-let-7b-3p                   7.106261         6.968846         6.984948
# rno-let-7b-5p                  14.688855        14.783330        14.838132
# ...                                  ...              ...              ...
# rno-miR-99b-5p                  9.407697         9.397417         9.334307
# rno-miR-9a-3p                   3.348652         4.912778         2.318916
# rno-miR-9a-5p                   4.856447         5.750674         3.996469
# rno-miR-9b-3p                   0.000000         1.753597         0.998118
# rno-miR-9b-5p                   0.000000         0.000000         0.000000
#
# [748 rows x 38 columns]

# %%
# Get the data straight (off the omnibus)
gse = GEOparse.get_GEO(geo="GSE159011", destdir=".")
# Out:
# 25-Aug-2025 11:37:00 DEBUG utils - Directory . already exists. Skipping.
# 25-Aug-2025 11:37:00 INFO GEOparse - File already exist: using local version.
# 25-Aug-2025 11:37:00 INFO GEOparse - Parsing ./GSE159011_family.soft.gz:
# 25-Aug-2025 11:37:00 DEBUG GEOparse - DATABASE: GeoMiame
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SERIES: GSE159011
# 25-Aug-2025 11:37:00 DEBUG GEOparse - PLATFORM: GPL25029
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817312
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817313
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817314
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817315
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817316
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817317
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817318
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817319
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817320
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817321
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817322
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817323
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817324
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817325
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817326
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817327
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817328
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817329
# 25-Aug-2025 11:37:00 DEBUG GEOparse - SAMPLE: GSM4817330

# %%
# And collect the metadata
meta = {}
for key in gse.gsms:
    # print(key)
    samp = gse.gsms[key].metadata['description'][0]
    characteristics = {}
    for item in gse.gsms[key].metadata['characteristics_ch1']:
        temp = item.split(': ')
        characteristics[temp[0]] = temp[1]

    if samp not in meta:
        meta[samp] = {}
        meta[samp] = characteristics
    else:
        meta[samp] = characteristics

rat_metadata = pd.DataFrame(meta).T
rat_metadata.to_csv('GSE159011_metadata.csv')

# %%
rat_metadata
# Out:
#                    strain    age       group
# 20657-001  Sprague-Dawley  Adult  Severe TBI
# 20657-002  Sprague-Dawley  Adult        Sham
# 20657-003  Sprague-Dawley  Adult    Mild TBI
# 20657-004  Sprague-Dawley  Adult        Sham
# 20657-005  Sprague-Dawley  Adult  Severe TBI
# 20657-006  Sprague-Dawley  Adult  Severe TBI
# 20657-007  Sprague-Dawley  Adult    Mild TBI
# 20657-008  Sprague-Dawley  Adult        Sham
# 20657-010  Sprague-Dawley  Adult        Sham
# 20657-011  Sprague-Dawley  Adult    Mild TBI
# 20657-012  Sprague-Dawley  Adult       Naive
# 20657-013  Sprague-Dawley  Adult  Severe TBI
# 20657-014  Sprague-Dawley  Adult       Naive
# 20657-015  Sprague-Dawley  Adult        Sham
# 20657-016  Sprague-Dawley  Adult       Naive
# 20657-017  Sprague-Dawley  Adult    Mild TBI
# 20657-018  Sprague-Dawley  Adult    Mild TBI
# 20657-019  Sprague-Dawley  Adult  Severe TBI
# 20657-020  Sprague-Dawley  Adult       Naive

# %%
# Filter metadata for Naive and Severe TBI groups
log2_df.columns = log2_df.columns.str.replace('-UMIs', '')
naive_samples = rat_metadata[rat_metadata['group'] == 'Naive'].index
severe_tbi_samples = rat_metadata[rat_metadata['group'] == 'Severe TBI'].index

# %%
# Subset expression data for Naive and Severe TBI samples
naive_expression = log2_df[naive_samples]
severe_tbi_expression = log2_df[severe_tbi_samples]

# %%
# Initialize a list to store results
diff_expression_results = []

# Iterate through each miRNA
for miRNA in log2_df.index:
    # Extract expression levels for this miRNA in Naive and Severe TBI groups
    naive_values = naive_expression.loc[miRNA]
    severe_tbi_values = severe_tbi_expression.loc[miRNA]
    
    # Perform the Mann-Whitney U test
    stat, p_value = mannwhitneyu(naive_values, severe_tbi_values, alternative='two-sided')
    
    # Store the results
    diff_expression_results.append({
        'miRNA': miRNA,
        'statistic': stat,
        'p_value': p_value
    })

# Convert the results to a DataFrame
diff_expression_df = pd.DataFrame(diff_expression_results)

# Drop out NaN from the p-values
diff_expression_df = diff_expression_df.dropna(subset=['p_value'])

# Apply multiple testing correction (e.g., Benjamini-Hochberg)
from statsmodels.stats.multitest import multipletests

diff_expression_df['adjusted_p_value'] = multipletests(diff_expression_df['p_value'], method='fdr_bh')[1]

# Apply multiple testing correction (e.g., Benjamini-Hochberg)
from statsmodels.stats.multitest import multipletests

diff_expression_df['Significant'], diff_expression_df['adjusted_p_value'], _, _ = multipletests(diff_expression_df['p_value'], method='fdr_bh')

# Sort the results by adjusted p-value
diff_expression_df = diff_expression_df.sort_values('p_value')
diff_expression_df
# Out:
#                miRNA  statistic   p_value  adjusted_p_value  Significant
# 129   rno-miR-15a-3p        0.0  0.015873          0.177209        False
# 508   rno-miR-381-3p        0.0  0.015873          0.177209        False
# 510   rno-miR-382-3p        0.0  0.015873          0.177209        False
# 665      rno-miR-668        0.0  0.015873          0.177209        False
# 663   rno-miR-667-3p        0.0  0.015873          0.177209        False
# ..               ...        ...       ...               ...          ...
# 194  rno-miR-196b-5p       10.0  1.000000          1.000000        False
# 621      rno-miR-568       10.0  1.000000          1.000000        False
# 180  rno-miR-193a-3p       10.0  1.000000          1.000000        False
# 453  rno-miR-3583-3p       10.0  1.000000          1.000000        False
# 310   rno-miR-29c-3p       10.0  1.000000          1.000000        False
#
# [748 rows x 5 columns]

# %%
# Initialize a list to store results
diff_expression_results = []

# Iterate through each miRNA
for miRNA in log2_df.index:
    # Extract expression levels for this miRNA in Naive and Severe TBI groups
    naive_values = naive_expression.loc[miRNA]
    severe_tbi_values = severe_tbi_expression.loc[miRNA]
    
    # Perform the Mann-Whitney U test
    stat, p_value = mannwhitneyu(naive_values, severe_tbi_values, alternative='two-sided')
    
    # Store the results
    diff_expression_results.append({
        'miRNA': miRNA,
        'statistic': stat,
        'p_value': p_value
    })

# Convert the results to a DataFrame
diff_expression_df = pd.DataFrame(diff_expression_results)

# Drop out NaN from the p-values
diff_expression_df = diff_expression_df.dropna(subset=['p_value'])

# Apply multiple testing correction (e.g., Benjamini-Hochberg)
from statsmodels.stats.multitest import multipletests

diff_expression_df['adjusted_p_value'] = multipletests(diff_expression_df['p_value'], method='fdr_bh')[1]

# Apply multiple testing correction (e.g., Benjamini-Hochberg)
from statsmodels.stats.multitest import multipletests

diff_expression_df['Significant'], diff_expression_df['adjusted_p_value'], _, _ = multipletests(diff_expression_df['p_value'], method='fdr_bh')

# Sort the results by adjusted p-value
diff_expression_df = diff_expression_df.sort_values('p_value')
diff_expression_df
# Out:
#                miRNA  statistic   p_value  adjusted_p_value  Significant
# 129   rno-miR-15a-3p        0.0  0.015873          0.177209        False
# 508   rno-miR-381-3p        0.0  0.015873          0.177209        False
# 510   rno-miR-382-3p        0.0  0.015873          0.177209        False
# 665      rno-miR-668        0.0  0.015873          0.177209        False
# 663   rno-miR-667-3p        0.0  0.015873          0.177209        False
# ..               ...        ...       ...               ...          ...
# 194  rno-miR-196b-5p       10.0  1.000000          1.000000        False
# 621      rno-miR-568       10.0  1.000000          1.000000        False
# 180  rno-miR-193a-3p       10.0  1.000000          1.000000        False
# 453  rno-miR-3583-3p       10.0  1.000000          1.000000        False
# 310   rno-miR-29c-3p       10.0  1.000000          1.000000        False
#
# [748 rows x 5 columns]
